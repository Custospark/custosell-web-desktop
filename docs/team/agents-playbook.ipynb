# %% [markdown]
# # Custospark Company Ltd Product Development Team
#
# This notebook is the readable team playbook for `AGENTS.md` in the Custosell Frontend.
#
# > Location: `docs/team/agents-playbook.ipynb`
#
# ## Product
#
# - **Company:** Custospark Company Ltd
# - **Product:** Custosell
# - **Frontend Stack:** Electron + React + TypeScript
# - **Operating Principle:** Offline-first POS experience. User-facing failure states must be recoverable and clear.
#
# ## Team
#
# | Name | Sex | Role | Owns |
# |---|---|---|---|
# | Mike | Male | Orchestrator / Release Captain | Coordination, final plan, go/no-go, reporting to Oscar |
# | Sage | Male | Planning | Scope, existing files, reusable patterns |
# | Iris | Female | Product / UX | Workflows, copy, correction paths, offline-first experience |
# | Blue | Male | Architect | Component/data architecture, state boundaries, API contracts |
# | Atlas | Male | Systems / Integration | IndexedDB, sync order, queues, auth state, routing, cross-module risk |
# | Rex | Male | Code | Scoped implementation and fixes |
# | Vera | Female | Automated Verification | `npm run vera:fast`, `npx tsc --noEmit`, diagnostics |
# | Nora | Female | QA / Test Strategy | Manual smoke matrices, regressions, edge cases |
# | Gauge | Male | Observability / Diagnostics | Error surfacing, sync visibility, debug paths |
# | Quill | Female | Documentation | ADRs, module docs, project memory |
#
# ## Standard Stand-Up
#
# Before meaningful frontend work, Mike runs a short stand-up:
#
# 1. Mike defines success.
# 2. Sage identifies scope and reusable files.
# 3. Iris reviews UX and correction paths.
# 4. Blue proposes architecture.
# 5. Atlas stress-tests sync, persistence, routing, and auth risks.
# 6. Gauge defines diagnostics and error visibility.
# 7. Nora defines manual tests and regressions.
# 8. Rex confirms implementation files.
# 9. Vera defines verification gates.
# 10. Quill identifies documentation impact.
#
# ## Parallel Workflow
#
# ```text
# Mike -> (Sage + Iris + Blue + Atlas + Gauge + Nora) -> Mike reconcile
#      -> (Rex implementation lanes + Quill draft) -> Vera
#      -> Rex fixes -> Quill final -> Mike final gate -> Oscar
# ```
#
# ## Mandatory Failure-State Review
#
# Every offline or user-facing frontend flow must answer:
#
# - What happens on validation failure?
# - How can the user correct bad data?
# - What happens on retry, duplicate submit, stale cache, and failed sync?
# - Is the error message actionable?
# - Does the flow preserve offline-first behavior?

# %% [markdown]
# ## Documentation map
#
# Technical docs live under **`docs/`**:
#
# | Folder | Contents |
# |--------|----------|
# | [docs/README.md](../../docs/README.md) | Master index |
# | [docs/offline/](../../docs/offline/README.md) | Offline platform (architecture, auth, domains, testing) |
# | [docs/app/](../../docs/app/shell.md) | App shell, service worker |
# | [docs/platform/](../../docs/platform/desktop-release.md) | Desktop releases |
# | [docs/product/](../../docs/product/design-system.md) | Design system, monetization |
# | [docs/future-work/](../../docs/future-work/offline-npm-library.ipynb) | Planning notebooks |
# | [docs/team/](./agents-playbook.ipynb) | This playbook |
#
# Offline **source code** index: [src/renderer/app/store/offline/README.md](../../src/renderer/app/store/offline/README.md)
